# %% [markdown]
# # Module

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import datetime as datetime
from math import isclose
from collections import Counter
import multiprocessing
import re
# Network libary
#import networkit as nk
import networkx as nx
from graph_tool.all import *
import stellargraph as sg
from stellargraph import StellarGraph, datasets
from stellargraph.datasets import IAEnronEmployees
from stellargraph.data import EdgeSplitter
from stellargraph import IndexedArray

# sklearn
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler

from stellargraph.data import BiasedRandomWalk
from gensim.models import Word2Vec
from stellargraph.mapper import FullBatchLinkGenerator, FullBatchNodeGenerator
from stellargraph.layer import GCN, LinkEmbedding
from stellargraph.data import BiasedRandomWalk
from stellargraph.data import UnsupervisedSampler
from stellargraph.mapper import Node2VecLinkGenerator, Node2VecNodeGenerator
from stellargraph.layer import Node2Vec, link_classification
from tensorflow import keras
# Out:
# 2023-11-11 19:21:51.059126: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-11 19:21:51.510635: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-11 19:21:52.394296: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-11-11 19:21:52.394401: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-11-11 19:21:52.394412: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-11-11 19:21:53.398180: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-11 19:21:54.955220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 23661 MB memory:  -> device: 0, name: Quadro P6000, pci bus id: 0000:37:00.0, compute capability: 6.1
# 2023-11-11 19:21:54.956526: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 23661 MB memory:  -> device: 1, name: Quadro P6000, pci bus id: 0000:86:00.0, compute capability: 6.1

# %% [markdown]
# # Load Data

# %%
loaded = np.load("/home/rh/Arbeitsraum/bitbucket/share/SLMI2/data/2022_6_2_law_500.npz",allow_pickle=True)

# %% [markdown]
# # Load train and test

# %%
#loaded = np.load("/home/rh/law_keiji_dyn_savez.npz",allow_pickle=True)
print(loaded.files)
edges_train = loaded["arr_0"]
labels_train = loaded["arr_1"]
edges_valid = loaded["arr_2"]
labels_valid = loaded["arr_3"]
edges_test = loaded["arr_4"]
labels_test = loaded["arr_5"]
features = loaded["arr_6"]
df_node2cnt = pd.DataFrame(loaded["arr_7"])

df_node2cnt.columns = ["index","node","cnt"]

node2index = dict()
for i in range(len(df_node2cnt)):
    node2index.update({df_node2cnt["node"].iloc[i]: df_node2cnt["index"].iloc[i]})
    

df_train_0 = pd.DataFrame(edges_train)
df_train_0[2] = labels_train
cond = df_train_0[2] == 1
df_train_1 = df_train_0.loc[cond].copy()
df_train = df_train_1[[0,1]].copy()
df_train.columns = ["source","target"]


df_train_0.columns = ["source","target","label"]

#df_train["source"] = df_train["source"].map(node2index)
#df_train["target"] = df_train["target"].map(node2index)
#df_train_0["source"] = df_train_0["source"].map(node2index)
#df_train_0["target"] = df_train_0["target"].map(node2index)

df_valid_0 = pd.DataFrame(edges_valid)
df_valid_0[2] = labels_valid
cond = df_valid_0[2] == 1
df_valid_1 = df_valid_0.loc[cond].copy()
df_valid = df_valid_1[[0,1]].copy()
df_valid.columns = ["source","target"]
df_valid_0.columns = ["source","target","label"]


#df_valid["source"] = df_valid["source"].map(node2index)
#df_valid["target"] = df_valid["target"].map(node2index)
#df_valid_0["source"] = df_valid_0["source"].map(node2index)
#df_valid_0["target"] = df_valid_0["target"].map(node2index)

df_test_0 = pd.DataFrame(edges_test)
df_test_0[2] = labels_test
cond = df_test_0[2] == 1
df_test_1 = df_test_0.loc[cond].copy()
df_test = df_test_1[[0,1]].copy()
df_test.columns = ["source","target"]
df_test_0.columns = ["source","target","label"]


#df_test["source"] = df_test["source"].map(node2index)
#df_test["target"] = df_test["target"].map(node2index)
#df_test_0["source"] = df_test_0["source"].map(node2index)
#df_test_0["target"] = df_test_0["target"].map(node2index)


df_node2cnt["node"] = df_node2cnt["node"].astype(str)
indexed_array = IndexedArray(features, index=list(df_node2cnt["node"]))
#indexed_array = IndexedArray( index=list(df_node2cnt["node"]))
tmp_nodes = list(set(df_train["source"]))
tmp_nodes.extend(list(set(df_train["target"])))
tmp_nodes = list(set(tmp_nodes))
# Out:
# ['arr_0', 'arr_1', 'arr_2', 'arr_3', 'arr_4', 'arr_5', 'arr_6', 'arr_7']

# %% [markdown]
# # Create Stellar Objects

# %%
df_train["source"] = df_train["source"].astype(str)
df_train["target"] = df_train["target"].astype(str)

df_test["source"] = df_test["source"].astype(str)
df_test["target"] = df_test["target"].astype(str)

graph_train = StellarGraph(nodes=indexed_array,edges=df_train)
graph_test = StellarGraph(nodes=indexed_array,edges=df_test)
#print(graph_train.info())
#graph_test = StellarGraph(nodes=df_nodes,edges=df_test)
#print(graph_test.info())
# weight_
#
#graph_test = StellarGraph(edges=df_test)
#graph = StellarGraph(edges=df_edges_2[["source","target","weight"]])
#edge_splitter_test = EdgeSplitter(graph)
#graph_test, examples_test, labels_test = edge_splitter_test.train_test_split(
#    p=0.1, method="global")
#print(graph_test.info())
#df_test = pd.DataFrame(graph_test.edges())
#len(df_test)
#X = graph_test.to_adjacency_matrix()
#edge_splitter_train = EdgeSplitter(graph_test, graph)
#graph_train, examples, labels = edge_splitter_train.train_test_split(
#    p=0.1, method="global")
#(examples_train,examples_model_selection,labels_train,
#    labels_model_selection,) = train_test_split(examples, labels, train_size=0.75, test_size=0.25)
#print(graph_train.info())
#df_train = pd.DataFrame(graph_train.edges())

# %%
print(graph_train.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 3521, Edges: 51430
#
#  Node types:
#   default: [3521]
#     Features: float64 vector, length 5677
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [51430]
#         Weights: all 1 (default)
#         Features: none

# %%
print(graph_test.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 3521, Edges: 17378
#
#  Node types:
#   default: [3521]
#     Features: float64 vector, length 5677
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [17378]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# # Run

# %%
train_gen = FullBatchLinkGenerator(graph_train, method="gcn")
train_flow = train_gen.flow(edges_train, labels_train)
test_gen = FullBatchLinkGenerator(graph_test, method="gcn")
test_flow = train_gen.flow(edges_test, labels_test)

gcn = GCN(
    layer_sizes=[250], activations=["relu"], 
    generator=train_gen, dropout=0.2
)

x_inp, x_out = gcn.in_out_tensors()
prediction = LinkEmbedding(activation="relu", method="ip")(x_out)
prediction = keras.layers.Reshape((-1,))(prediction)

model = keras.Model(inputs=x_inp, outputs=prediction)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.005),
    loss=keras.losses.binary_crossentropy
)

#model.compile(loss='categorical_crossentropy', optimizer='adadelta',metrics=['acc'])
init_train_metrics = model.evaluate(train_flow)
init_test_metrics = model.evaluate(test_flow)

print("\nTrain Set Metrics of the initial (untrained) model:")
print(init_train_metrics)
#for name, val in zip(model.metrics_names, init_train_metrics):
#   print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the initial (untrained) model:")
#for name, val in zip(model.metrics_names, init_test_metrics):
#    print("\t{}: {:0.4f}".format(name, val))
print(init_test_metrics)
# Out:
# Using GCN (local pooling) filters...
# Using GCN (local pooling) filters...
# 1/1 [==============================] - 1s 792ms/step - loss: 1.5985
# 1/1 [==============================] - 0s 200ms/step - loss: 1.6108
#
# Train Set Metrics of the initial (untrained) model:
# 1.598541021347046
#
# Test Set Metrics of the initial (untrained) model:
# 1.6107686758041382

# %% [markdown]
# # Run

# %%
# %%time
epochs = 1000
history = model.fit(
    train_flow, epochs=epochs, 
     validation_data=test_flow, verbose=2, shuffle=False)
# Out:
# Epoch 1/1000
# 1/1 - 1s - loss: 1.5963 - val_loss: 0.6400 - 1s/epoch - 1s/step
# Epoch 2/1000
# 1/1 - 1s - loss: 0.6372 - val_loss: 0.4812 - 583ms/epoch - 583ms/step
# Epoch 3/1000
# 1/1 - 0s - loss: 0.4785 - val_loss: 0.4292 - 427ms/epoch - 427ms/step
# Epoch 4/1000
# 1/1 - 1s - loss: 0.4267 - val_loss: 0.4292 - 512ms/epoch - 512ms/step
# Epoch 5/1000
# 1/1 - 0s - loss: 0.4267 - val_loss: 0.4572 - 416ms/epoch - 416ms/step
# Epoch 6/1000
# 1/1 - 0s - loss: 0.4551 - val_loss: 0.4936 - 450ms/epoch - 450ms/step
# Epoch 7/1000
# 1/1 - 0s - loss: 0.4919 - val_loss: 0.5231 - 431ms/epoch - 431ms/step
# Epoch 8/1000
# 1/1 - 0s - loss: 0.5211 - val_loss: 0.5380 - 408ms/epoch - 408ms/step
# Epoch 9/1000
# 1/1 - 0s - loss: 0.5362 - val_loss: 0.5383 - 438ms/epoch - 438ms/step
# Epoch 10/1000
# 1/1 - 0s - loss: 0.5369 - val_loss: 0.5288 - 423ms/epoch - 423ms/step
# Epoch 11/1000
# 1/1 - 0s - loss: 0.5270 - val_loss: 0.5144 - 425ms/epoch - 425ms/step
# Epoch 12/1000
# 1/1 - 0s - loss: 0.5123 - val_loss: 0.4998 - 435ms/epoch - 435ms/step
# Epoch 13/1000
# 1/1 - 0s - loss: 0.4980 - val_loss: 0.4867 - 404ms/epoch - 404ms/step
# Epoch 14/1000
# 1/1 - 0s - loss: 0.4849 - val_loss: 0.4765 - 411ms/epoch - 411ms/step
# Epoch 15/1000
# 1/1 - 0s - loss: 0.4743 - val_loss: 0.4684 - 414ms/epoch - 414ms/step
# Epoch 16/1000
# 1/1 - 0s - loss: 0.4662 - val_loss: 0.4620 - 421ms/epoch - 421ms/step
# Epoch 17/1000
# 1/1 - 0s - loss: 0.4597 - val_loss: 0.4567 - 430ms/epoch - 430ms/step
# Epoch 502/1000
# 1/1 - 0s - loss: 0.3092 - val_loss: 0.3146 - 421ms/epoch - 421ms/step
# Epoch 503/1000
# 1/1 - 0s - loss: 0.3090 - val_loss: 0.3147 - 409ms/epoch - 409ms/step
# Epoch 504/1000
# 1/1 - 0s - loss: 0.3089 - val_loss: 0.3145 - 444ms/epoch - 444ms/step
# Epoch 505/1000
# 1/1 - 0s - loss: 0.3090 - val_loss: 0.3144 - 425ms/epoch - 425ms/step
# Epoch 506/1000
# 1/1 - 0s - loss: 0.3087 - val_loss: 0.3142 - 418ms/epoch - 418ms/step
# Epoch 507/1000
# 1/1 - 0s - loss: 0.3084 - val_loss: 0.3140 - 443ms/epoch - 443ms/step
# Epoch 508/1000
# 1/1 - 0s - loss: 0.3086 - val_loss: 0.3140 - 425ms/epoch - 425ms/step
# Epoch 509/1000
# 1/1 - 0s - loss: 0.3085 - val_loss: 0.3140 - 414ms/epoch - 414ms/step
# Epoch 510/1000
# 1/1 - 0s - loss: 0.3084 - val_loss: 0.3139 - 428ms/epoch - 428ms/step
# Epoch 511/1000
# 1/1 - 0s - loss: 0.3082 - val_loss: 0.3141 - 430ms/epoch - 430ms/step
# Epoch 512/1000
# 1/1 - 0s - loss: 0.3081 - val_loss: 0.3140 - 431ms/epoch - 431ms/step
# Epoch 513/1000
# 1/1 - 0s - loss: 0.3080 - val_loss: 0.3139 - 435ms/epoch - 435ms/step
# Epoch 514/1000
# 1/1 - 0s - loss: 0.3079 - val_loss: 0.3138 - 429ms/epoch - 429ms/step
# Epoch 515/1000
# 1/1 - 0s - loss: 0.3079 - val_loss: 0.3136 - 410ms/epoch - 410ms/step
# Epoch 516/1000
# 1/1 - 0s - loss: 0.3077 - val_loss: 0.3135 - 425ms/epoch - 425ms/step
# Epoch 517/1000
# 1/1 - 0s - loss: 0.3077 - val_loss: 0.3134 - 411ms/epoch - 411ms/step
# Epoch 518/1000
# 1/1 - 0s - loss: 0.3075 - val_loss: 0.3133 - 444ms/epoch - 444ms/step
# Epoch 519/1000
# 1/1 - 0s - loss: 0.3072 - val_loss: 0.3132 - 432ms/epoch - 432ms/step
# Epoch 520/1000
# 1/1 - 0s - loss: 0.3073 - val_loss: 0.3127 - 411ms/epoch - 411ms/step
# Epoch 521/1000
# 1/1 - 0s - loss: 0.3071 - val_loss: 0.3125 - 414ms/epoch - 414ms/step
# Epoch 522/1000
# 1/1 - 0s - loss: 0.3070 - val_loss: 0.3124 - 435ms/epoch - 435ms/step
# Epoch 523/1000
# 1/1 - 0s - loss: 0.3070 - val_loss: 0.3122 - 416ms/epoch - 416ms/step
# Epoch 524/1000
# 1/1 - 0s - loss: 0.3066 - val_loss: 0.3121 - 438ms/epoch - 438ms/step
# Epoch 525/1000
# 1/1 - 0s - loss: 0.3065 - val_loss: 0.3121 - 420ms/epoch - 420ms/step
# Epoch 526/1000
# 1/1 - 0s - loss: 0.3064 - val_loss: 0.3121 - 438ms/epoch - 438ms/step
# Epoch 527/1000
# 1/1 - 0s - loss: 0.3063 - val_loss: 0.3120 - 449ms/epoch - 449ms/step
# Epoch 528/1000
# 1/1 - 0s - loss: 0.3064 - val_loss: 0.3119 - 429ms/epoch - 429ms/step
# Epoch 529/1000
# 1/1 - 0s - loss: 0.3061 - val_loss: 0.3119 - 431ms/epoch - 431ms/step
# Epoch 530/1000
# 1/1 - 0s - loss: 0.3059 - val_loss: 0.3119 - 420ms/epoch - 420ms/step
# Epoch 531/1000
# 1/1 - 0s - loss: 0.3060 - val_loss: 0.3118 - 432ms/epoch - 432ms/step
# Epoch 532/1000
# 1/1 - 0s - loss: 0.3058 - val_loss: 0.3117 - 446ms/epoch - 446ms/step
# Epoch 533/1000
# 1/1 - 0s - loss: 0.3056 - val_loss: 0.3116 - 431ms/epoch - 431ms/step
# Epoch 534/1000
# 1/1 - 0s - loss: 0.3056 - val_loss: 0.3114 - 438ms/epoch - 438ms/step
# Epoch 535/1000
# 1/1 - 0s - loss: 0.3054 - val_loss: 0.3112 - 439ms/epoch - 439ms/step
# Epoch 536/1000
# 1/1 - 0s - loss: 0.3054 - val_loss: 0.3115 - 412ms/epoch - 412ms/step
# Epoch 537/1000
# 1/1 - 0s - loss: 0.3051 - val_loss: 0.3116 - 436ms/epoch - 436ms/step
# Epoch 538/1000
# 1/1 - 0s - loss: 0.3051 - val_loss: 0.3115 - 436ms/epoch - 436ms/step
# Epoch 539/1000
# 1/1 - 0s - loss: 0.3050 - val_loss: 0.3113 - 427ms/epoch - 427ms/step
# Epoch 540/1000
# 1/1 - 0s - loss: 0.3050 - val_loss: 0.3111 - 429ms/epoch - 429ms/step
# Epoch 541/1000
# 1/1 - 0s - loss: 0.3048 - val_loss: 0.3110 - 429ms/epoch - 429ms/step
# Epoch 542/1000
# 1/1 - 0s - loss: 0.3049 - val_loss: 0.3109 - 415ms/epoch - 415ms/step
# Epoch 543/1000
# 1/1 - 0s - loss: 0.3047 - val_loss: 0.3108 - 426ms/epoch - 426ms/step
# Epoch 544/1000
# 1/1 - 0s - loss: 0.3043 - val_loss: 0.3109 - 412ms/epoch - 412ms/step
# Epoch 545/1000
# 1/1 - 0s - loss: 0.3041 - val_loss: 0.3105 - 428ms/epoch - 428ms/step
# Epoch 546/1000
# 1/1 - 0s - loss: 0.3042 - val_loss: 0.3104 - 444ms/epoch - 444ms/step
# Epoch 547/1000
# 1/1 - 0s - loss: 0.3040 - val_loss: 0.3105 - 421ms/epoch - 421ms/step
# Epoch 548/1000
# 1/1 - 0s - loss: 0.3041 - val_loss: 0.3104 - 427ms/epoch - 427ms/step
# Epoch 549/1000
# 1/1 - 0s - loss: 0.3041 - val_loss: 0.3103 - 441ms/epoch - 441ms/step
# Epoch 550/1000
# 1/1 - 0s - loss: 0.3038 - val_loss: 0.3101 - 431ms/epoch - 431ms/step
# Epoch 551/1000
# 1/1 - 0s - loss: 0.3037 - val_loss: 0.3101 - 440ms/epoch - 440ms/step
# Epoch 552/1000
# 1/1 - 0s - loss: 0.3036 - val_loss: 0.3100 - 435ms/epoch - 435ms/step
# Epoch 553/1000
# 1/1 - 0s - loss: 0.3037 - val_loss: 0.3101 - 438ms/epoch - 438ms/step
# Epoch 554/1000
# 1/1 - 0s - loss: 0.3033 - val_loss: 0.3098 - 416ms/epoch - 416ms/step
# Epoch 555/1000
# 1/1 - 0s - loss: 0.3032 - val_loss: 0.3098 - 434ms/epoch - 434ms/step
# Epoch 556/1000
# 1/1 - 0s - loss: 0.3034 - val_loss: 0.3096 - 429ms/epoch - 429ms/step
# Epoch 557/1000
# 1/1 - 0s - loss: 0.3033 - val_loss: 0.3097 - 427ms/epoch - 427ms/step
# Epoch 558/1000
# 1/1 - 0s - loss: 0.3037 - val_loss: 0.3096 - 425ms/epoch - 425ms/step
# Epoch 559/1000
# 1/1 - 0s - loss: 0.3034 - val_loss: 0.3093 - 421ms/epoch - 421ms/step
# Epoch 560/1000
# 1/1 - 0s - loss: 0.3033 - val_loss: 0.3092 - 437ms/epoch - 437ms/step
# Epoch 561/1000
# 1/1 - 0s - loss: 0.3027 - val_loss: 0.3092 - 419ms/epoch - 419ms/step
# Epoch 562/1000
# 1/1 - 0s - loss: 0.3026 - val_loss: 0.3091 - 405ms/epoch - 405ms/step
# Epoch 563/1000
# 1/1 - 0s - loss: 0.3023 - val_loss: 0.3091 - 461ms/epoch - 461ms/step
# Epoch 564/1000
# 1/1 - 0s - loss: 0.3022 - val_loss: 0.3090 - 484ms/epoch - 484ms/step
# Epoch 565/1000
# 1/1 - 0s - loss: 0.3023 - val_loss: 0.3086 - 447ms/epoch - 447ms/step
# Epoch 566/1000
# 1/1 - 0s - loss: 0.3019 - val_loss: 0.3087 - 417ms/epoch - 417ms/step
# ...
# Epoch 814/1000
# 1/1 - 0s - loss: 0.2849 - val_loss: 0.2926 - 438ms/epoch - 438ms/step
# Epoch 815/1000
# 1/1 - 0s - loss: 0.2847 - val_loss: 0.2925 - 415ms/epoch - 415ms/step
# Epoch 816/1000
# 1/1 - 0s - loss: 0.2852 - val_loss: 0.2926 - 429ms/epoch - 429ms/step
# Epoch 817/1000
# 1/1 - 0s - loss: 0.2850 - val_loss: 0.2926 - 431ms/epoch - 431ms/step
# Epoch 818/1000
# 1/1 - 0s - loss: 0.2848 - val_loss: 0.2925 - 419ms/epoch - 419ms/step
# Epoch 819/1000
# 1/1 - 0s - loss: 0.2850 - val_loss: 0.2924 - 439ms/epoch - 439ms/step
# Epoch 820/1000
# 1/1 - 0s - loss: 0.2846 - val_loss: 0.2923 - 421ms/epoch - 421ms/step
# Epoch 821/1000
# 1/1 - 0s - loss: 0.2845 - val_loss: 0.2930 - 417ms/epoch - 417ms/step
# Epoch 822/1000
# 1/1 - 0s - loss: 0.2842 - val_loss: 0.2929 - 420ms/epoch - 420ms/step
# Epoch 823/1000
# 1/1 - 0s - loss: 0.2840 - val_loss: 0.2926 - 421ms/epoch - 421ms/step
# Epoch 824/1000
# 1/1 - 0s - loss: 0.2845 - val_loss: 0.2927 - 429ms/epoch - 429ms/step
# Epoch 825/1000
# 1/1 - 0s - loss: 0.2844 - val_loss: 0.2930 - 432ms/epoch - 432ms/step
# Epoch 826/1000
# 1/1 - 0s - loss: 0.2842 - val_loss: 0.2932 - 415ms/epoch - 415ms/step
# Epoch 827/1000
# 1/1 - 0s - loss: 0.2845 - val_loss: 0.2933 - 435ms/epoch - 435ms/step
# Epoch 828/1000
# 1/1 - 0s - loss: 0.2840 - val_loss: 0.2928 - 424ms/epoch - 424ms/step
# Epoch 829/1000
# 1/1 - 0s - loss: 0.2838 - val_loss: 0.2931 - 421ms/epoch - 421ms/step
# Epoch 830/1000
# 1/1 - 0s - loss: 0.2839 - val_loss: 0.2937 - 431ms/epoch - 431ms/step
# Epoch 831/1000
# 1/1 - 0s - loss: 0.2840 - val_loss: 0.2945 - 433ms/epoch - 433ms/step
# Epoch 832/1000
# 1/1 - 0s - loss: 0.2851 - val_loss: 0.2948 - 442ms/epoch - 442ms/step
# Epoch 833/1000
# 1/1 - 0s - loss: 0.2850 - val_loss: 0.2952 - 421ms/epoch - 421ms/step
# Epoch 834/1000
# 1/1 - 0s - loss: 0.2857 - val_loss: 0.2953 - 427ms/epoch - 427ms/step
# Epoch 835/1000
# 1/1 - 0s - loss: 0.2853 - val_loss: 0.2952 - 420ms/epoch - 420ms/step
# Epoch 836/1000
# 1/1 - 0s - loss: 0.2853 - val_loss: 0.2949 - 422ms/epoch - 422ms/step
# Epoch 837/1000
# 1/1 - 0s - loss: 0.2852 - val_loss: 0.2944 - 443ms/epoch - 443ms/step
# Epoch 838/1000
# 1/1 - 0s - loss: 0.2851 - val_loss: 0.2939 - 428ms/epoch - 428ms/step
# Epoch 839/1000
# 1/1 - 0s - loss: 0.2844 - val_loss: 0.2933 - 446ms/epoch - 446ms/step
# Epoch 840/1000
# 1/1 - 0s - loss: 0.2840 - val_loss: 0.2930 - 421ms/epoch - 421ms/step
# Epoch 841/1000
# 1/1 - 0s - loss: 0.2835 - val_loss: 0.2927 - 440ms/epoch - 440ms/step
# Epoch 842/1000
# 1/1 - 0s - loss: 0.2836 - val_loss: 0.2925 - 428ms/epoch - 428ms/step
# Epoch 843/1000
# 1/1 - 0s - loss: 0.2830 - val_loss: 0.2923 - 413ms/epoch - 413ms/step
# Epoch 844/1000
# 1/1 - 0s - loss: 0.2829 - val_loss: 0.2927 - 436ms/epoch - 436ms/step
# Epoch 845/1000
# 1/1 - 0s - loss: 0.2831 - val_loss: 0.2929 - 420ms/epoch - 420ms/step
# Epoch 846/1000
# 1/1 - 0s - loss: 0.2832 - val_loss: 0.2930 - 418ms/epoch - 418ms/step
# Epoch 847/1000
# 1/1 - 0s - loss: 0.2832 - val_loss: 0.2930 - 425ms/epoch - 425ms/step
# Epoch 848/1000
# 1/1 - 0s - loss: 0.2833 - val_loss: 0.2926 - 425ms/epoch - 425ms/step
# Epoch 849/1000
# 1/1 - 0s - loss: 0.2830 - val_loss: 0.2925 - 433ms/epoch - 433ms/step
# Epoch 850/1000
# 1/1 - 0s - loss: 0.2836 - val_loss: 0.2924 - 422ms/epoch - 422ms/step
# Epoch 851/1000
# 1/1 - 0s - loss: 0.2829 - val_loss: 0.2919 - 416ms/epoch - 416ms/step
# Epoch 852/1000
# 1/1 - 0s - loss: 0.2831 - val_loss: 0.2918 - 426ms/epoch - 426ms/step
# Epoch 853/1000
# 1/1 - 0s - loss: 0.2826 - val_loss: 0.2917 - 441ms/epoch - 441ms/step
# Epoch 854/1000
# 1/1 - 0s - loss: 0.2828 - val_loss: 0.2917 - 420ms/epoch - 420ms/step
# Epoch 855/1000
# 1/1 - 0s - loss: 0.2824 - val_loss: 0.2916 - 415ms/epoch - 415ms/step
# Epoch 856/1000
# 1/1 - 0s - loss: 0.2823 - val_loss: 0.2914 - 417ms/epoch - 417ms/step
# Epoch 857/1000
# 1/1 - 0s - loss: 0.2823 - val_loss: 0.2913 - 407ms/epoch - 407ms/step
# Epoch 858/1000
# 1/1 - 0s - loss: 0.2827 - val_loss: 0.2916 - 422ms/epoch - 422ms/step
# Epoch 859/1000
# 1/1 - 0s - loss: 0.2821 - val_loss: 0.2915 - 410ms/epoch - 410ms/step
# Epoch 860/1000
# 1/1 - 0s - loss: 0.2821 - val_loss: 0.2915 - 409ms/epoch - 409ms/step
# Epoch 861/1000
# 1/1 - 0s - loss: 0.2820 - val_loss: 0.2915 - 400ms/epoch - 400ms/step
# Epoch 862/1000
# 1/1 - 0s - loss: 0.2824 - val_loss: 0.2913 - 404ms/epoch - 404ms/step
# Epoch 863/1000
# 1/1 - 0s - loss: 0.2817 - val_loss: 0.2915 - 439ms/epoch - 439ms/step
# Epoch 864/1000
# 1/1 - 0s - loss: 0.2821 - val_loss: 0.2911 - 408ms/epoch - 408ms/step
# Epoch 865/1000
# 1/1 - 0s - loss: 0.2815 - val_loss: 0.2909 - 431ms/epoch - 431ms/step
# Epoch 866/1000
# 1/1 - 0s - loss: 0.2814 - val_loss: 0.2909 - 421ms/epoch - 421ms/step
# Epoch 867/1000
# 1/1 - 0s - loss: 0.2818 - val_loss: 0.2907 - 414ms/epoch - 414ms/step
# Epoch 868/1000
# 1/1 - 0s - loss: 0.2815 - val_loss: 0.2907 - 453ms/epoch - 453ms/step
# Epoch 869/1000
# 1/1 - 0s - loss: 0.2812 - val_loss: 0.2906 - 418ms/epoch - 418ms/step
# Epoch 870/1000
# 1/1 - 0s - loss: 0.2813 - val_loss: 0.2903 - 429ms/epoch - 429ms/step
# Epoch 871/1000
# 1/1 - 0s - loss: 0.2815 - val_loss: 0.2905 - 437ms/epoch - 437ms/step
# Epoch 872/1000
# 1/1 - 0s - loss: 0.2815 - val_loss: 0.2907 - 415ms/epoch - 415ms/step
# Epoch 873/1000
# 1/1 - 0s - loss: 0.2817 - val_loss: 0.2911 - 440ms/epoch - 440ms/step
# Epoch 874/1000
# 1/1 - 0s - loss: 0.2819 - val_loss: 0.2918 - 429ms/epoch - 429ms/step
# Epoch 875/1000
# 1/1 - 0s - loss: 0.2827 - val_loss: 0.2921 - 439ms/epoch - 439ms/step
# Epoch 876/1000
# 1/1 - 0s - loss: 0.2826 - val_loss: 0.2923 - 442ms/epoch - 442ms/step
# Epoch 877/1000
# 1/1 - 0s - loss: 0.2829 - val_loss: 0.2923 - 411ms/epoch - 411ms/step
# Epoch 878/1000
# 1/1 - 0s - loss: 0.2828 - val_loss: 0.2925 - 438ms/epoch - 438ms/step
# Epoch 879/1000
# 1/1 - 0s - loss: 0.2834 - val_loss: 0.2924 - 440ms/epoch - 440ms/step
# Epoch 880/1000
# 1/1 - 0s - loss: 0.2834 - val_loss: 0.2925 - 421ms/epoch - 421ms/step
# Epoch 881/1000
# 1/1 - 0s - loss: 0.2833 - val_loss: 0.2920 - 425ms/epoch - 425ms/step
# Epoch 882/1000
# 1/1 - 0s - loss: 0.2838 - val_loss: 0.2919 - 423ms/epoch - 423ms/step
# Epoch 883/1000
# 1/1 - 0s - loss: 0.2829 - val_loss: 0.2916 - 428ms/epoch - 428ms/step
# Epoch 884/1000
# 1/1 - 0s - loss: 0.2829 - val_loss: 0.2915 - 441ms/epoch - 441ms/step
# Epoch 885/1000
# 1/1 - 0s - loss: 0.2828 - val_loss: 0.2913 - 428ms/epoch - 428ms/step
# Epoch 886/1000
# 1/1 - 0s - loss: 0.2827 - val_loss: 0.2907 - 410ms/epoch - 410ms/step
# Epoch 887/1000
# 1/1 - 0s - loss: 0.2822 - val_loss: 0.2909 - 405ms/epoch - 405ms/step
# Epoch 888/1000
# 1/1 - 0s - loss: 0.2821 - val_loss: 0.2913 - 411ms/epoch - 411ms/step
# Epoch 889/1000
# 1/1 - 0s - loss: 0.2819 - val_loss: 0.2912 - 425ms/epoch - 425ms/step
# Epoch 890/1000
# 1/1 - 0s - loss: 0.2821 - val_loss: 0.2915 - 419ms/epoch - 419ms/step
# Epoch 891/1000
# 1/1 - 0s - loss: 0.2824 - val_loss: 0.2916 - 429ms/epoch - 429ms/step
# Epoch 892/1000
# 1/1 - 0s - loss: 0.2819 - val_loss: 0.2918 - 411ms/epoch - 411ms/step
# Epoch 893/1000
# 1/1 - 0s - loss: 0.2819 - val_loss: 0.2918 - 429ms/epoch - 429ms/step
# Epoch 894/1000
# 1/1 - 0s - loss: 0.2822 - val_loss: 0.2917 - 420ms/epoch - 420ms/step
# Epoch 895/1000
# 1/1 - 0s - loss: 0.2821 - val_loss: 0.2920 - 421ms/epoch - 421ms/step
# Epoch 896/1000
# 1/1 - 0s - loss: 0.2818 - val_loss: 0.2919 - 421ms/epoch - 421ms/step
# Epoch 897/1000
# 1/1 - 0s - loss: 0.2819 - val_loss: 0.2919 - 417ms/epoch - 417ms/step
# Epoch 898/1000
# 1/1 - 0s - loss: 0.2817 - val_loss: 0.2918 - 417ms/epoch - 417ms/step
# Epoch 899/1000
# 1/1 - 0s - loss: 0.2815 - val_loss: 0.2915 - 408ms/epoch - 408ms/step
# Epoch 900/1000
# 1/1 - 0s - loss: 0.2811 - val_loss: 0.2912 - 422ms/epoch - 422ms/step
# Epoch 901/1000
# 1/1 - 0s - loss: 0.2810 - val_loss: 0.2911 - 434ms/epoch - 434ms/step
# Epoch 902/1000
# 1/1 - 0s - loss: 0.2809 - val_loss: 0.2906 - 409ms/epoch - 409ms/step
# Epoch 903/1000
# 1/1 - 0s - loss: 0.2806 - val_loss: 0.2902 - 416ms/epoch - 416ms/step
# Epoch 904/1000
# 1/1 - 0s - loss: 0.2801 - val_loss: 0.2897 - 419ms/epoch - 419ms/step
# Epoch 905/1000
# 1/1 - 0s - loss: 0.2797 - val_loss: 0.2898 - 412ms/epoch - 412ms/step
# Epoch 906/1000
# 1/1 - 0s - loss: 0.2796 - val_loss: 0.2896 - 416ms/epoch - 416ms/step
# Epoch 907/1000
# 1/1 - 0s - loss: 0.2794 - val_loss: 0.2894 - 415ms/epoch - 415ms/step
# Epoch 908/1000
# 1/1 - 0s - loss: 0.2794 - val_loss: 0.2891 - 410ms/epoch - 410ms/step
# Epoch 909/1000
# 1/1 - 0s - loss: 0.2793 - val_loss: 0.2887 - 413ms/epoch - 413ms/step
# Epoch 910/1000
# 1/1 - 0s - loss: 0.2794 - val_loss: 0.2887 - 411ms/epoch - 411ms/step
# Epoch 911/1000
# 1/1 - 0s - loss: 0.2792 - val_loss: 0.2888 - 425ms/epoch - 425ms/step
# Epoch 912/1000
# 1/1 - 0s - loss: 0.2791 - val_loss: 0.2885 - 425ms/epoch - 425ms/step
# Epoch 913/1000
# 1/1 - 0s - loss: 0.2791 - val_loss: 0.2884 - 415ms/epoch - 415ms/step
# Epoch 914/1000
# 1/1 - 0s - loss: 0.2790 - val_loss: 0.2884 - 428ms/epoch - 428ms/step
# Epoch 915/1000
# 1/1 - 0s - loss: 0.2795 - val_loss: 0.2882 - 438ms/epoch - 438ms/step
# Epoch 916/1000
# 1/1 - 0s - loss: 0.2789 - val_loss: 0.2883 - 429ms/epoch - 429ms/step
# Epoch 917/1000
# 1/1 - 0s - loss: 0.2792 - val_loss: 0.2885 - 435ms/epoch - 435ms/step
# Epoch 918/1000
# 1/1 - 0s - loss: 0.2793 - val_loss: 0.2886 - 426ms/epoch - 426ms/step
# Epoch 919/1000
# 1/1 - 0s - loss: 0.2791 - val_loss: 0.2886 - 427ms/epoch - 427ms/step
# Epoch 920/1000
# 1/1 - 0s - loss: 0.2788 - val_loss: 0.2889 - 429ms/epoch - 429ms/step
# Epoch 921/1000
# 1/1 - 0s - loss: 0.2787 - val_loss: 0.2889 - 432ms/epoch - 432ms/step
# Epoch 922/1000
# 1/1 - 0s - loss: 0.2785 - val_loss: 0.2889 - 428ms/epoch - 428ms/step
# Epoch 923/1000
# 1/1 - 0s - loss: 0.2786 - val_loss: 0.2892 - 465ms/epoch - 465ms/step
# Epoch 924/1000
# 1/1 - 0s - loss: 0.2788 - val_loss: 0.2892 - 420ms/epoch - 420ms/step
# Epoch 925/1000
# 1/1 - 0s - loss: 0.2785 - val_loss: 0.2892 - 426ms/epoch - 426ms/step
# Epoch 926/1000
# 1/1 - 0s - loss: 0.2785 - val_loss: 0.2891 - 410ms/epoch - 410ms/step
# Epoch 927/1000
# 1/1 - 0s - loss: 0.2784 - val_loss: 0.2890 - 417ms/epoch - 417ms/step
# Epoch 928/1000
# 1/1 - 0s - loss: 0.2782 - val_loss: 0.2889 - 402ms/epoch - 402ms/step
# Epoch 929/1000
# 1/1 - 0s - loss: 0.2784 - val_loss: 0.2888 - 425ms/epoch - 425ms/step
# Epoch 930/1000
# 1/1 - 0s - loss: 0.2787 - val_loss: 0.2887 - 418ms/epoch - 418ms/step
# Epoch 931/1000
# 1/1 - 0s - loss: 0.2783 - val_loss: 0.2886 - 419ms/epoch - 419ms/step
# Epoch 932/1000
# 1/1 - 0s - loss: 0.2780 - val_loss: 0.2882 - 411ms/epoch - 411ms/step
# Epoch 933/1000
# 1/1 - 0s - loss: 0.2777 - val_loss: 0.2881 - 426ms/epoch - 426ms/step
# Epoch 934/1000
# 1/1 - 0s - loss: 0.2780 - val_loss: 0.2880 - 434ms/epoch - 434ms/step
# Epoch 935/1000
# 1/1 - 0s - loss: 0.2781 - val_loss: 0.2881 - 420ms/epoch - 420ms/step
# Epoch 936/1000
# 1/1 - 0s - loss: 0.2778 - val_loss: 0.2881 - 416ms/epoch - 416ms/step
# Epoch 937/1000
# 1/1 - 0s - loss: 0.2778 - val_loss: 0.2880 - 410ms/epoch - 410ms/step
# Epoch 938/1000
# 1/1 - 0s - loss: 0.2779 - val_loss: 0.2879 - 416ms/epoch - 416ms/step
# Epoch 939/1000
# 1/1 - 0s - loss: 0.2777 - val_loss: 0.2877 - 416ms/epoch - 416ms/step
# Epoch 940/1000
# 1/1 - 0s - loss: 0.2775 - val_loss: 0.2876 - 425ms/epoch - 425ms/step
# Epoch 941/1000
# 1/1 - 0s - loss: 0.2775 - val_loss: 0.2872 - 414ms/epoch - 414ms/step
# Epoch 942/1000
# 1/1 - 0s - loss: 0.2773 - val_loss: 0.2871 - 407ms/epoch - 407ms/step
# Epoch 943/1000
# 1/1 - 0s - loss: 0.2776 - val_loss: 0.2870 - 420ms/epoch - 420ms/step
# Epoch 944/1000
# 1/1 - 0s - loss: 0.2774 - val_loss: 0.2871 - 412ms/epoch - 412ms/step
# Epoch 945/1000
# 1/1 - 0s - loss: 0.2775 - val_loss: 0.2871 - 409ms/epoch - 409ms/step
# Epoch 946/1000
# 1/1 - 0s - loss: 0.2781 - val_loss: 0.2876 - 411ms/epoch - 411ms/step
# Epoch 947/1000
# 1/1 - 0s - loss: 0.2779 - val_loss: 0.2876 - 415ms/epoch - 415ms/step
# Epoch 948/1000
# 1/1 - 0s - loss: 0.2780 - val_loss: 0.2877 - 418ms/epoch - 418ms/step
# Epoch 949/1000
# 1/1 - 0s - loss: 0.2776 - val_loss: 0.2877 - 428ms/epoch - 428ms/step
# Epoch 950/1000
# 1/1 - 0s - loss: 0.2781 - val_loss: 0.2877 - 425ms/epoch - 425ms/step
# Epoch 951/1000
# 1/1 - 0s - loss: 0.2778 - val_loss: 0.2875 - 407ms/epoch - 407ms/step
# Epoch 952/1000
# 1/1 - 0s - loss: 0.2777 - val_loss: 0.2873 - 416ms/epoch - 416ms/step
# Epoch 953/1000
# 1/1 - 0s - loss: 0.2775 - val_loss: 0.2871 - 414ms/epoch - 414ms/step
# Epoch 954/1000
# 1/1 - 0s - loss: 0.2775 - val_loss: 0.2870 - 419ms/epoch - 419ms/step
# Epoch 955/1000
# 1/1 - 0s - loss: 0.2771 - val_loss: 0.2867 - 430ms/epoch - 430ms/step
# Epoch 956/1000
# 1/1 - 0s - loss: 0.2771 - val_loss: 0.2866 - 416ms/epoch - 416ms/step
# Epoch 957/1000
# 1/1 - 0s - loss: 0.2770 - val_loss: 0.2866 - 424ms/epoch - 424ms/step
# Epoch 958/1000
# 1/1 - 0s - loss: 0.2769 - val_loss: 0.2870 - 406ms/epoch - 406ms/step
# Epoch 959/1000
# 1/1 - 0s - loss: 0.2767 - val_loss: 0.2873 - 423ms/epoch - 423ms/step
# Epoch 960/1000
# 1/1 - 0s - loss: 0.2769 - val_loss: 0.2874 - 429ms/epoch - 429ms/step
# Epoch 961/1000
# 1/1 - 0s - loss: 0.2765 - val_loss: 0.2875 - 424ms/epoch - 424ms/step
# Epoch 962/1000
# 1/1 - 0s - loss: 0.2767 - val_loss: 0.2875 - 428ms/epoch - 428ms/step
# Epoch 963/1000
# 1/1 - 0s - loss: 0.2769 - val_loss: 0.2874 - 421ms/epoch - 421ms/step
# Epoch 964/1000
# 1/1 - 0s - loss: 0.2767 - val_loss: 0.2871 - 433ms/epoch - 433ms/step
# Epoch 965/1000
# 1/1 - 0s - loss: 0.2768 - val_loss: 0.2869 - 433ms/epoch - 433ms/step
# Epoch 966/1000
# 1/1 - 0s - loss: 0.2764 - val_loss: 0.2867 - 413ms/epoch - 413ms/step
# Epoch 967/1000
# 1/1 - 0s - loss: 0.2766 - val_loss: 0.2864 - 418ms/epoch - 418ms/step
# Epoch 968/1000
# 1/1 - 0s - loss: 0.2763 - val_loss: 0.2861 - 414ms/epoch - 414ms/step
# Epoch 969/1000
# 1/1 - 0s - loss: 0.2761 - val_loss: 0.2858 - 410ms/epoch - 410ms/step
# Epoch 970/1000
# 1/1 - 0s - loss: 0.2759 - val_loss: 0.2860 - 418ms/epoch - 418ms/step
# Epoch 971/1000
# 1/1 - 0s - loss: 0.2761 - val_loss: 0.2861 - 407ms/epoch - 407ms/step
# Epoch 972/1000
# 1/1 - 0s - loss: 0.2756 - val_loss: 0.2860 - 418ms/epoch - 418ms/step
# Epoch 973/1000
# 1/1 - 0s - loss: 0.2755 - val_loss: 0.2862 - 421ms/epoch - 421ms/step
# Epoch 974/1000
# 1/1 - 0s - loss: 0.2756 - val_loss: 0.2862 - 410ms/epoch - 410ms/step
# Epoch 975/1000
# 1/1 - 0s - loss: 0.2756 - val_loss: 0.2861 - 425ms/epoch - 425ms/step
# Epoch 976/1000
# 1/1 - 0s - loss: 0.2756 - val_loss: 0.2861 - 407ms/epoch - 407ms/step
# Epoch 977/1000
# 1/1 - 0s - loss: 0.2754 - val_loss: 0.2860 - 416ms/epoch - 416ms/step
# Epoch 978/1000
# 1/1 - 0s - loss: 0.2754 - val_loss: 0.2859 - 415ms/epoch - 415ms/step
# Epoch 979/1000
# 1/1 - 0s - loss: 0.2754 - val_loss: 0.2860 - 432ms/epoch - 432ms/step
# Epoch 980/1000
# 1/1 - 0s - loss: 0.2758 - val_loss: 0.2861 - 421ms/epoch - 421ms/step
# Epoch 981/1000
# 1/1 - 0s - loss: 0.2755 - val_loss: 0.2860 - 412ms/epoch - 412ms/step
# Epoch 982/1000
# 1/1 - 0s - loss: 0.2755 - val_loss: 0.2857 - 412ms/epoch - 412ms/step
# Epoch 983/1000
# 1/1 - 0s - loss: 0.2754 - val_loss: 0.2858 - 421ms/epoch - 421ms/step
# Epoch 984/1000
# 1/1 - 0s - loss: 0.2751 - val_loss: 0.2859 - 438ms/epoch - 438ms/step
# Epoch 985/1000
# 1/1 - 0s - loss: 0.2751 - val_loss: 0.2859 - 422ms/epoch - 422ms/step
# Epoch 986/1000
# 1/1 - 0s - loss: 0.2753 - val_loss: 0.2857 - 431ms/epoch - 431ms/step
# Epoch 987/1000
# 1/1 - 0s - loss: 0.2748 - val_loss: 0.2855 - 413ms/epoch - 413ms/step
# Epoch 988/1000
# 1/1 - 0s - loss: 0.2749 - val_loss: 0.2855 - 407ms/epoch - 407ms/step
# Epoch 989/1000
# 1/1 - 0s - loss: 0.2749 - val_loss: 0.2854 - 419ms/epoch - 419ms/step
# Epoch 990/1000
# 1/1 - 0s - loss: 0.2750 - val_loss: 0.2858 - 427ms/epoch - 427ms/step
# Epoch 991/1000
# 1/1 - 0s - loss: 0.2749 - val_loss: 0.2860 - 434ms/epoch - 434ms/step
# Epoch 992/1000
# 1/1 - 0s - loss: 0.2752 - val_loss: 0.2860 - 420ms/epoch - 420ms/step
# Epoch 993/1000
# 1/1 - 0s - loss: 0.2750 - val_loss: 0.2859 - 434ms/epoch - 434ms/step
# Epoch 994/1000
# 1/1 - 0s - loss: 0.2751 - val_loss: 0.2860 - 402ms/epoch - 402ms/step
# Epoch 995/1000
# 1/1 - 0s - loss: 0.2748 - val_loss: 0.2861 - 417ms/epoch - 417ms/step
# Epoch 996/1000
# 1/1 - 0s - loss: 0.2748 - val_loss: 0.2859 - 425ms/epoch - 425ms/step
# Epoch 997/1000
# 1/1 - 0s - loss: 0.2746 - val_loss: 0.2857 - 427ms/epoch - 427ms/step
# Epoch 998/1000
# 1/1 - 0s - loss: 0.2747 - val_loss: 0.2855 - 417ms/epoch - 417ms/step
# Epoch 999/1000
# 1/1 - 0s - loss: 0.2747 - val_loss: 0.2856 - 426ms/epoch - 426ms/step
# Epoch 1000/1000
# 1/1 - 0s - loss: 0.2745 - val_loss: 0.2855 - 442ms/epoch - 442ms/step
# CPU times: user 5min 27s, sys: 3min 22s, total: 8min 50s
# Wall time: 7min 33s

# %% [markdown]
# # Evaluate

# %%
train_metrics = model.evaluate(train_flow)
test_metrics = model.evaluate(test_flow)
print("\nTrain Set Metrics of the initial (untrained) model:")
print(init_train_metrics)
#for name, val in zip(model.metrics_names, init_train_metrics):
#   print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the initial (untrained) model:")
#for name, val in zip(model.metrics_names, init_test_metrics):
#    print("\t{}: {:0.4f}".format(name, val))
print(init_test_metrics)
# Out:
# 1/1 [==============================] - 0s 232ms/step - loss: 0.2739
# 1/1 [==============================] - 0s 234ms/step - loss: 0.2855
#
# Train Set Metrics of the initial (untrained) model:
# 1.598541021347046
#
# Test Set Metrics of the initial (untrained) model:
# 1.6107686758041382

# %%
sg.utils.plot_history(history)

# %% [markdown]
# # Final Score

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import average_precision_score, precision_recall_curve

predict_y = model.predict(test_flow)

fpr, tpr, thresholds = metrics.roc_curve(labels_test, predict_y[0,:])
auc = metrics.auc(fpr, tpr)
print(auc)
# Average precision score
average_precision = average_precision_score(labels_test, predict_y[0,:])
print(average_precision)
# Data to plot precision - recall curve
precision, recall, thresholds = precision_recall_curve(labels_test, predict_y[0,:])
# Use AUC function to calculate the area under the curve of precision recall curve
auc_precision_recall = metrics.auc(recall, precision)
print(auc_precision_recall)
# Out:
# 1/1 [==============================] - 0s 333ms/step
# 0.9037004097062782
# 0.6800407401993287
# 0.6800110483349524

# %% [markdown]
# # Save

# %%
df_pred = pd.DataFrame({"pred":predict_y[0,:]})
header = "./results/"
file_out = header + "GCN_pred.csv"
print(file_out)
df_pred.to_csv(file_out,index=False)
print(len(df_pred))
file_out_3 = header + "_df_node2cnt.csv"
df_node2cnt.to_csv(file_out_3,index=False)
# Out:
# ./results/GCN_pred.csv
# 104268

# %% [markdown]
# # Get Embedding

# %%
embedding_model = keras.Model(inputs=x_inp, outputs=x_out)
generator = FullBatchNodeGenerator(graph_train, method="gcn")
all_nodes = list(df_node2cnt["node"])
all_gen = generator.flow(all_nodes)
emb = embedding_model.predict(all_gen)
X = emb.squeeze(0)
X.shape

file_out_2 = header +  "_GCN_node_emb.npz"
np.savez_compressed(file_out_2, X)
# Out:
# Using GCN (local pooling) filters...
# WARNING:tensorflow:Model was constructed with shape (1, None, 2) for input KerasTensor(type_spec=TensorSpec(shape=(1, None, 2), dtype=tf.int32, name='input_2'), name='input_2', description="created by layer 'input_2'"), but it was called on an input with incompatible shape (None, None).
# 1/1 [==============================] - 0s 260ms/step

# %% [markdown]
# # Load embedding

# %%
loaded = np.load(file_out_2)
X = loaded["arr_0"]

# %%
transform = TSNE  # or PCA
trans = transform(n_components=2)
X_reduced = trans.fit_transform(X)
X_reduced.shape
fig, ax = plt.subplots(figsize=(7, 7))
ax.scatter(
    X_reduced[:, 0],
    X_reduced[:, 1],
    #c=node_subjects.astype("category").cat.codes,
    cmap="jet",
    alpha=0.7,
)
ax.set(
    aspect="equal",
    xlabel="$X_1$",
    ylabel="$X_2$",
    title=f"{transform.__name__} visualization of GCN embeddings",
)
# Out:
# [None,
#  Text(0.5, 0, '$X_1$'),
#  Text(0, 0.5, '$X_2$'),
#  Text(0.5, 1.0, 'TSNE visualization of GCN embeddings')]
